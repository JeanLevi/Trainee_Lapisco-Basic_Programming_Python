# %%
import numpy as np
import matplotlib.pyplot as plt

# Sinal contínuo
t = np.linspace(0, 1, 1000)
frequencia_sinal = 20
sinal_continuo = np.sin(2 * np.pi * frequencia_sinal * t)

# Transformada de Fourier
transformada = np.fft.fft(sinal_continuo)
frequencias = np.fft.fftfreq(len(t), t[1] - t[0])

plt.figure(figsize=(8, 6))
plt.plot(frequencias, np.abs(transformada))
plt.xlabel('Frequência (Hz)')
plt.ylabel('Magnitude')
plt.title('Transformada de Fourier')
plt.grid(True)
plt.show()

# Filtragem

# Adicionar ruído ao sinal
ruido = 0.5 * np.random.randn(len(t))
sinal_com_ruido = sinal_continuo + ruido

# Filtragem Passa-baixa
frequencia_corte = 15  # Frequência de corte do filtro
transformada = np.fft.fft(sinal_com_ruido)
transformada[frequencias > frequencia_corte] = 0
sinal_filtrado = np.fft.ifft(transformada)

plt.figure(figsize=(10, 6))
plt.plot(t, sinal_continuo, label='Sinal Original')
plt.plot(t, sinal_com_ruido, 'r', label='Sinal com Ruído')
plt.plot(t, sinal_filtrado, 'g', label='Sinal Filtrado')
plt.legend()
plt.xlabel('Tempo (s)')
plt.ylabel('Amplitude')
plt.title('Filtragem Passa-baixa')
plt.grid(True)
plt.show()


#Análise Espectral

# Transformada de Fourier e análise espectral
transformada = np.fft.fft(sinal_continuo)
frequencias = np.fft.fftfreq(len(t), t[1] - t[0])
espectro = np.abs(transformada)

# Plotar o espectro de frequência
plt.figure(figsize=(8, 6))
plt.plot(frequencias, espectro)
plt.xlabel('Frequência (Hz)')
plt.ylabel('Magnitude')
plt.title('Análise Espectral')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# 2.

# %% [markdown]
# 2.1

# %%
from google.colab import drive
drive.mount('/content/drive')

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Carregar a imagem
imagem = cv2.imread("/content/drive/MyDrive/Classroom/Trainee Lapisco - Programação Básica(Python)/Jean Levi Cavalcante Linhares - Captura de tela 2023-07-22 080126.png")

# Verificar se a imagem foi carregada corretamente
if imagem is None:
    print("Não foi possível carregar a imagem. Verifique o caminho e o nome do arquivo.")
else:
    # Converter a imagem para o formato RGB
    novo_tamanho = (150, 200)
    imagem_redimensionada = cv2.resize(imagem, novo_tamanho)

# Plotar a imagem redimensionada
plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(imagem_redimensionada, cv2.COLOR_BGR2RGB))
plt.title("Imagem Redimensionada")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-5ad584d3022a> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 import cv2
#       5 import numpy as np
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
2.2

# %%
from google.colab import drive
drive.mount('/content/drive')

import cv2
import numpy as np
import matplotlib.pyplot as plt


imagem = cv2.imread("/content/drive/MyDrive/Classroom/Trainee Lapisco - Programação Básica(Python)/Jean Levi Cavalcante Linhares - download.jpg")


if imagem is None:
    print("Não foi possível carregar a imagem. Verifique o caminho e o nome do arquivo.")
else:

    novo_tamanho = (500, 400)
    imagem_redimensionada = cv2.resize(imagem, novo_tamanho)

plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(imagem_redimensionada, cv2.COLOR_BGR2RGB))
plt.title("Imagem Redimensionada")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-91151be3b49c> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 import cv2
#       5 import numpy as np
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# 2.3

# %%
from google.colab import drive
drive.mount('/content/drive')

import cv2
import numpy as np
import matplotlib.pyplot as plt


imagem = cv2.imread("/content/drive/MyDrive/Classroom/Trainee Lapisco - Programação Básica(Python)/Jean Levi Cavalcante Linhares - images.jpg")


if imagem is None:
    print("Não foi possível carregar a imagem. Verifique o caminho e o nome do arquivo.")
else:
    novo_tamanho = (400, 500)
    imagem_redimensionada = cv2.resize(imagem, novo_tamanho)

plt.figure(figsize=(8, 6))
plt.imshow(cv2.cvtColor(imagem_redimensionada, cv2.COLOR_BGR2RGB))
plt.title("Imagem Redimensionada")
plt.axis("off")
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
